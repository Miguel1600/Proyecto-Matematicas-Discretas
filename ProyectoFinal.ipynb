# %%
import itertools


elementos = [1,2,3,4,5]



flag=True
M=[[10,15,7,10,30],[28,13,12,40,6],[33,9,15,7,18],[14,27,14,23,17],[30,14,12,15,18]]
cont=0
CostoAsignacion=0

permutaciones = list(itertools.permutations(elementos))




for asignacion in permutaciones:
    for i in range(len(asignacion)):
        
        a=asignacion[i]-1
        CostoAsignacion=M[i][a]+CostoAsignacion
    if(flag):
        costomin=CostoAsignacion
        flag=False
    if(CostoAsignacion<=costomin):
        costomin=CostoAsignacion
        minasignacion=asignacion
    print(asignacion,"costo:",CostoAsignacion,"minutos") 
    CostoAsignacion=0
  
print("##################")
print("La asignacion con menor costo es")

for i in range(len(minasignacion)):
    print("El enfermero",i+1,"visita al paciente",minasignacion[i])

print("con un costo de", costomin,"minutos")
# Out:
# (1, 2, 3, 4, 5) costo: 79 minutos
# (1, 2, 3, 5, 4) costo: 70 minutos
# (1, 2, 4, 3, 5) costo: 62 minutos
# (1, 2, 4, 5, 3) costo: 59 minutos
# (1, 2, 5, 3, 4) costo: 70 minutos
# (1, 2, 5, 4, 3) costo: 76 minutos
# (1, 3, 2, 4, 5) costo: 72 minutos
# (1, 3, 2, 5, 4) costo: 63 minutos
# (1, 3, 4, 2, 5) costo: 74 minutos
# (1, 3, 4, 5, 2) costo: 60 minutos
# (1, 3, 5, 2, 4) costo: 82 minutos
# (1, 3, 5, 4, 2) costo: 77 minutos
# (1, 4, 2, 3, 5) costo: 91 minutos
# (1, 4, 2, 5, 3) costo: 88 minutos
# (1, 4, 3, 2, 5) costo: 110 minutos
# (1, 4, 3, 5, 2) costo: 96 minutos
# (1, 4, 5, 2, 3) costo: 107 minutos
# (1, 4, 5, 3, 2) costo: 96 minutos
# (1, 5, 2, 3, 4) costo: 54 minutos
# (1, 5, 2, 4, 3) costo: 60 minutos
# (1, 5, 3, 2, 4) costo: 73 minutos
# (1, 5, 3, 4, 2) costo: 68 minutos
# (1, 5, 4, 2, 3) costo: 62 minutos
# (1, 5, 4, 3, 2) costo: 51 minutos
# (2, 1, 3, 4, 5) costo: 99 minutos
# (2, 1, 3, 5, 4) costo: 90 minutos
# (2, 1, 4, 3, 5) costo: 82 minutos
# ...
